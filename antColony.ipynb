# %% [markdown]
# #Ant Colony

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Bibliotecas necessárias

# %%
# !pip install ACO-Pants
# https://pypi.org/project/ACO-Pants/
# Out:
# Collecting ACO-Pants
#   Downloading ACO-Pants-0.5.2.tar.gz (15 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ACO-Pants
#   Building wheel for ACO-Pants (setup.py) ... done
#   Created wheel for ACO-Pants: filename=ACO_Pants-0.5.2-py3-none-any.whl size=18841 sha256=59547d057a5cf4be7f3d693e3491c2a56bce14d9831f0f35c5bfb35c90fa7332
#   Stored in directory: /root/.cache/pip/wheels/18/20/45/4dc8bf8059c641765ecbbaf092ec25ad79f7deaa51662a68c8
# Successfully built ACO-Pants
# Installing collected packages: ACO-Pants
# Successfully installed ACO-Pants-0.5.2

# %%
import pants
import math
import random
from plot import plot

# %% [markdown]
# ###Preparar solução

# %%
# semente: para reprodução de resultados
random.seed(1)

# %%
# cria-se os nós do problema
nodes = []
for _ in range(20):
  x = random.uniform(-10, 10)
  y = random.uniform(-10, 10)
  nodes.append((x, y))

# %%
nodes
# Out:
# [(-7.312715117751976, 6.9486747387446535),
#  (5.275492379532281, -4.898619485211566),
#  (-0.09129825816118142, -1.010178704225238),
#  (3.031859454455258, 5.7744670227102635),
#  (-8.122808264515303, -9.433050469559873),
#  (6.715302078397393, -1.344658641898933),
#  (5.245601649158839, -9.957878932977787),
#  (-1.092256118903972, 4.430800646815651),
#  (-5.424755574590947, 8.905413911078448),
#  (8.028549152229672, -9.388200339328929),
#  (-9.491082780130784, 0.8282494558699316),
#  (8.782983255570212, -2.375915246235751),
#  (-5.668012057387733, -1.5576684883456533),
#  (-9.419184248502642, -5.566166674539299),
#  (-1.2422481269885584, -0.0837551723629879),
#  (-5.338310994848547, -5.382669169180314),
#  (-5.624379253246228, -0.8079306852453279),
#  (-4.204367708190288, -9.570205894681823),
#  (6.751559513251458, 1.129086453048668),
#  (2.8458872586489115, -6.281874682105646)]

# %%
# função de distância: custo de ir de um nó a outro
def euclidean(a, b):
    return math.sqrt(pow(a[0] - b[0], 2) + pow(a[1] - b[1], 2))

# %%
# cria-se o "mundo"
world = pants.World(nodes, euclidean)

# %% [markdown]
# ###Solve

# %%
# solver
solver = pants.Solver(ants=30, limit=1000)

# %%
# RUN
solution = solver.solve(world)  # retorna a melhor solução

# %% [markdown]
# ###Resultados

# %%
# Avalia resultados
print(solution.distance)
print(solution.tour)    # Nós visitados em ordem
print(solution.visited) # Índices dos nós visitados em ordem
# Out:
# 83.4653307890112
# [(2.8458872586489115, -6.281874682105646), (5.275492379532281, -4.898619485211566), (-0.09129825816118142, -1.010178704225238), (-1.2422481269885584, -0.0837551723629879), (-5.624379253246228, -0.8079306852453279), (-5.668012057387733, -1.5576684883456533), (-5.338310994848547, -5.382669169180314), (-4.204367708190288, -9.570205894681823), (-8.122808264515303, -9.433050469559873), (-9.419184248502642, -5.566166674539299), (-9.491082780130784, 0.8282494558699316), (-7.312715117751976, 6.9486747387446535), (-5.424755574590947, 8.905413911078448), (-1.092256118903972, 4.430800646815651), (3.031859454455258, 5.7744670227102635), (6.751559513251458, 1.129086453048668), (6.715302078397393, -1.344658641898933), (8.782983255570212, -2.375915246235751), (8.028549152229672, -9.388200339328929), (5.245601649158839, -9.957878932977787)]
# [19, 1, 2, 14, 16, 12, 15, 17, 4, 13, 10, 0, 8, 7, 3, 18, 5, 11, 9, 6]

# %%
# Gráfico
plot(solution.tour)
